# %% [markdown]
# # **Importing the client file and Analysis**

# %%
import pandas as pd
df = pd.read_csv('Client input.csv')
df
# Out:
#    distance (in km)  days
# 0               170     4
# 1               220     5
# 2               340     7
# 3               470    10
# 4               520    12
# 5               600    14
# 6               750    20

# %% [markdown]
# # **Importing the ML model**

# %%
import pickle 
with open('/content/budgetmodel', 'rb')  as f:
  reg = pickle.load(f)

# %% [markdown]
# # **Predict the amount**

# %%
budgetdf = reg.predict(df)
budgetdf
# Out:
# array([ 7353.12665607, 10379.86221516, 17550.45045045, 25513.5400106 ,
#        28774.21833598, 33710.57233704, 43492.6073132 ])

# %%
df['budget'] = budgetdf
df['budget']
# Out:
# 0     7353.126656
# 1    10379.862215
# 2    17550.450450
# 3    25513.540011
# 4    28774.218336
# 5    33710.572337
# 6    43492.607313
# Name: budget, dtype: float64

# %%
df.to_csv('Predicted amount.csv', index = 'False')
